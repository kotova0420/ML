# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

# %%
matplotlib.style.use('ggplot')

# %%
# Импорт таблиц

X = pd.read_csv('data/1_x.csv',  header=None)
Y = pd.read_csv('data/1_y.csv',  header=None)

# %%
X.head()
# Out:
#           0         1         2         3         4         5         6
# 0  1.599865  0.340598 -0.603400  0.150586 -0.209677  0.955045  0.347682
# 1  1.472656  0.466832 -1.947130  0.625906  0.589354  0.753521 -2.138552
# 2  0.279378 -1.717121  0.251069  0.730013  0.301801 -0.206711  0.894811
# 3  0.450771  1.133196 -0.294028 -2.595338  0.313911  1.953527  0.359938
# 4  1.507042  0.932115 -0.789549  1.043712 -1.404000 -0.124354 -0.921117

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       125 non-null    float64
#  1   1       125 non-null    float64
#  2   2       125 non-null    float64
#  3   3       125 non-null    float64
#  4   4       125 non-null    float64
#  5   5       125 non-null    float64
#  6   6       125 non-null    float64
# dtypes: float64(7)
# memory usage: 7.0 KB

# %%
Y.head()
# Out:
#             0
# 0  101.507602
# 1  -65.305680
# 2  152.189336
# 3 -109.702103
# 4  -11.188624

# %%
Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       125 non-null    float64
# dtypes: float64(1)
# memory usage: 1.1 KB

# %%
# Создаем пустую модель

reg = linear_model.LinearRegression()

# %%
# Обучение машины с помощью метода fit(X, Y) - расчет параметров для указанных данных

reg.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Методом score можно узнать значение метрики эффективности полученной модели

reg.score(X, Y)
# Out:
# 0.9950477220889815

# %%
# Получаем коэффициенты bn

reg.coef_
# Out:
# array([[51.02147295, -0.26872966, 23.76334279, 69.95555491, 57.05175017,
#          0.39731156, 82.01281498]])

# %%
reg.intercept_
# Out:
# array([0.88462783])

# %%
# Метод predict() рассчитывает теоретические значения признака

y_pred = reg.predict(X)
len(y_pred)
# Out:
# 125

# %%
fig, ax = plt.subplots()
ax.plot(np.array(Y), color='red', label='real')
ax.plot(y_pred, color='green', label='pred')
ax.legend()
fig.set_figheight(6)
fig.set_figwidth(10)
plt.savefig('noll.png')
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)

ax = fig.add_subplot(projection='3d')
fig.suptitle('Visualise predict for X0 and X1', fontsize=44)

zline = np.array(y_pred)
xline = np.array(X[0])
yline = np.array(X[1])
ax.scatter3D(xline, yline, zline, c = xline)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.savefig('first.png')

plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)

ax = fig.add_subplot(projection='3d')
fig.suptitle('Visualise predict for X3 and X4', fontsize=44)

zline = np.array(y_pred)
xline = np.array(X[3])
yline = np.array(X[4])
ax.scatter3D(xline, yline, zline, c = xline)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.savefig('second.png')

plt.show()
